# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
csv_data = pd.read_csv('all_data.csv')
csv_data = csv_data.sort_values(by='Year')
display(csv_data)
print(csv_data.info())
print(csv_data.describe())
# Out:
#                      Country  Year  Life expectancy at birth (years)  \
# 0                      Chile  2000                              77.3
# 16                     China  2000                              71.7
# 80                  Zimbabwe  2000                              46.0
# 64  United States of America  2000                              76.8
# 32                   Germany  2000                              78.0
# ..                       ...   ...                               ...
# 63                    Mexico  2015                              76.7
# 31                     China  2015                              76.1
# 15                     Chile  2015                              80.5
# 79  United States of America  2015                              79.3
# 95                  Zimbabwe  2015                              60.7
#
#              GDP
# 0   7.786093e+10
# 16  1.211350e+12
# 80  6.689958e+09
# 64  1.030000e+13
# 32  1.949950e+12
# ..           ...
# ...

# %%
country = csv_data.Country
year = csv_data.Year
life_exp = csv_data['Life expectancy at birth (years)']
gdp = csv_data.GDP

sns.boxplot(x = 'Year', y = 'Life expectancy at birth (years)', palette = "pastel", data = csv_data)
plt.title("Expectativa de vida desde o ano 2000 até 2015 nos 6 países")
plt.xlabel("Anos")
plt.ylabel("Expectativa de vida (anos)")
plt.xticks(rotation=30)
plt.show()
plt.clf()

plt.bar(year, life_exp)
plt.title("Expectativa de vida desde o ano 2000 até 2015 nos 6 países")
plt.xlabel("Anos")
plt.ylabel("Expectativa de vida (anos)")
plt.show()
plt.clf()

# %%
sns.boxplot(x = 'Year', y = 'GDP', palette = "pastel", data = csv_data)
plt.title("Produto Interno Bruto dos 6 países do ano 2000 a 2015")
plt.xlabel("Anos")
plt.ylabel("Produto Interno Bruto ($)")
plt.xticks(rotation=30)
plt.show()
plt.clf()

plt.bar(year, gdp)
plt.title("Expectativa de vida dos 6 países do ano 2000 até 2015")
plt.xlabel("Anos")
plt.ylabel("Produto Interno Bruto ($)")
plt.show()
plt.clf()

# %%
sns.boxplot(x = 'Country', y = 'Life expectancy at birth (years)', palette = "pastel", data = csv_data)
plt.xlabel("Anos")
plt.ylabel("Expectativa de vida (anos)")
plt.title("Expectativa de vida por país")
plt.xticks(rotation=30)
plt.show()
plt.clf()

sns.boxplot(x = 'Country', y = 'GDP', palette = "pastel", data = csv_data)
plt.xlabel("Anos")
plt.ylabel("Produto Interno Bruto ($)")
plt.title("Produto Interno Bruto por país")
plt.xticks(rotation=30)
plt.show()
plt.clf()

# %%
countries_strings = csv_data.Country.unique()

for country in countries_strings:
    data_per_country = csv_data[csv_data.Country == country]
    plt.plot(data_per_country['Year'], data_per_country['Life expectancy at birth (years)'], label = country)
    plt.legend(fontsize='small')
    plt.title("Evolução da expectativa de vida por país")
    plt.xlabel("Anos")
    plt.ylabel("Expectativa de vida (anos)")
plt.show()
plt.clf()

for country in countries_strings:
    data_per_country = csv_data[csv_data.Country == country]
    plt.plot(data_per_country['Year'], data_per_country['GDP'], label = country)
    plt.legend(fontsize='small')
    plt.title("Evolução do PIB por país")
    plt.xlabel("Anos")
    plt.ylabel("Produto Interno Bruto ($)")
plt.show()
plt.clf()

# %%
# plt.scatter(gdp, life_exp)

for country in countries_strings:
    data_per_country = csv_data[csv_data.Country == country]
    sns.lmplot(x = "Life expectancy at birth (years)", y = "GDP", data = data_per_country, line_kws={'color': 'black'}, lowess=True, scatter_kws={"s": 10})
    plt.title("Correlação entre o PIB e a expectativa de vida no " + country)
    plt.xlabel("Expectativa de vida (anos)")
    plt.ylabel("Produto Interno Bruto ($)")
    plt.show()
    plt.clf()

# %%
plt.hist(life_exp)
plt.title("Histograma da expectativa de vida dos 6 países")
plt.xlabel("Expectativa de vida (anos)")
plt.ylabel("Frequência")
plt.show()
plt.clf()

plt.hist(gdp)
plt.title("Histograma do produto interno bruto dos 6 países")
plt.xlabel("Produto Interno Bruto ($)")
plt.ylabel("Frequência")
plt.show()
plt.clf()

# %%
# Caso queira saber o histograma do produto interno bruto ou expectativa de vida por país

# for country in countries_strings:
#     data_per_country = csv_data[csv_data.Country == country]
#     plt.hist(data_per_country['GDP'])
#     plt.title("Histograma do produto interno bruto do " + country)
#     plt.xlabel("Produto Interno Bruto ($)")
#     plt.ylabel("Frequência")
#     plt.show()
#     plt.clf()
#     plt.show()
#     plt.clf()
